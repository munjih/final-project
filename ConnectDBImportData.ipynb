# %%
import pandas as pd
import numpy as np
import re
from sqlalchemy import create_engine
from sqlalchemy.sql import text
import psycopg2
from config import db_password

# %%
#create directory path if needed
#file_dir = 'C:/Users/03michelleh/Desktop/ClassFolder/Module20/'

# %%
covid_data = pd.read_csv('US_counties_COVID19_health_weather_data_replaced_na.csv',low_memory=False )

# %%
covid_data.head(5)
# Out:
#    index        date   county    state   fips  cases  deaths  \
# 0      0  2020-05-29  Autauga  Alabama  01001    212       3
# 1      1  2020-05-29  Baldwin  Alabama  01003    282       9
# 2      2  2020-05-29  Barbour  Alabama  01005    147       1
# 3      3  2020-05-29     Bibb  Alabama  01007     71       1
# 4      4  2020-05-29   Blount  Alabama  01009     60       1
#
#   stay_at_home_announced stay_at_home_effective  total_population  ...  \
# 0                    yes                    yes             55049  ...
# 1                    yes                    yes            199510  ...
# 2                    yes                    yes             26614  ...
# 3                    yes                    yes             22572  ...
# 4                    yes                    yes             57704  ...
#
#    percentile_rank_minorities  percentile_rank_limited_english_abilities  \
# 0                      0.6339                                     0.5355
# ...

# %%
(covid_data.columns.tolist())
# Out:
# ['index',
#  'date',
#  'county',
#  'state',
#  'fips',
#  'cases',
#  'deaths',
#  'stay_at_home_announced',
#  'stay_at_home_effective',
#  'total_population',
#  'area_sqmi',
#  'population_density_per_sqmi',
#  'num_deaths',
#  'years_of_potential_life_lost_rate',
#  'percent_fair_or_poor_health',
#  'average_number_of_physically_unhealthy_days',
#  'average_number_of_mentally_unhealthy_days',
#  'percent_low_birthweight',
#  'percent_smokers',
#  'percent_adults_with_obesity',
#  'food_environment_index',
#  'percent_physically_inactive',
#  'percent_with_access_to_exercise_opportunities',
#  'percent_excessive_drinking',
#  'num_alcohol_impaired_driving_deaths',
#  'num_driving_deaths',
#  'percent_driving_deaths_with_alcohol_involvement',
#  'num_chlamydia_cases',
#  'chlamydia_rate',
#  'teen_birth_rate',
#  'num_uninsured',
#  'percent_uninsured',
#  'num_primary_care_physicians',
#  'primary_care_physicians_rate',
#  'num_dentists',
#  'dentist_rate',
# ...

# %%
try:
    db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/final_project"
    engine = create_engine(db_string)
    print("Connection made WOOTWOOT!")
except:
    print('Could not connect to database')
# Out:
# Connection made WOOTWOOT!

# %%
rows_imported = 0
for data in pd.read_csv('US_counties_COVID19_health_weather_data_replaced_na.csv', chunksize=1000000):

    print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end='')
    data.to_sql(name='covid_table', con=engine, if_exists='append')
    rows_imported += len(data)

    print(f'Done.')
# Out:
# importing rows 0 to 2957...Done.
